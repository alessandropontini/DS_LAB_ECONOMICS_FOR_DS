# %% [markdown]
# <a href="https://colab.research.google.com/github/god-data-unimib/DS_LAB_ECONOMICS_FOR_DS/blob/main/pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Installare pycaret

# %%
# ! pip install pycaret
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
from pycaret.utils import enable_colab
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
enable_colab()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Colab mode enabled.

# %% [markdown]
# Get data

# %%
directory = 'https://raw.githubusercontent.com/god-data-unimib/DS_LAB_ECONOMICS_FOR_DS/main/dataset1/telecom_users.csv'

df = pd.read_csv(filepath_or_buffer=directory)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
df.columns
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Index(['Unnamed: 0', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# CLASSIFICAZIONE

# %%
from pycaret.classification import *
exp_clf = setup(df, target = 'Churn')
# Out:
#                                Description             Value
# 0                               session_id              7773
# 1                                   Target             Churn
# 2                              Target Type            Binary
# 3                            Label Encoded     No: 0, Yes: 1
# 4                            Original Data        (5986, 22)
# 5                           Missing Values             False
# 6                         Numeric Features                 3
# 7                     Categorical Features                18
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set      (4190, 4368)
# 12                    Transformed Test Set      (1796, 4368)
# 13                      Shuffle Train-Test              True
# ...

# %%
# best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.8005  0.8377  0.5358  0.6531
# gbc          Gradient Boosting Classifier    0.7995  0.8472  0.4981  0.6660
# ada                  Ada Boost Classifier    0.7983  0.8469  0.5295  0.6483
# lightgbm  Light Gradient Boosting Machine    0.7912  0.8305  0.5233  0.6312
# rf               Random Forest Classifier    0.7895  0.8263  0.4382  0.6578
# ridge                    Ridge Classifier    0.7871  0.0000  0.4363  0.6499
# et                 Extra Trees Classifier    0.7797  0.8159  0.4400  0.6222
# dt               Decision Tree Classifier    0.7749  0.6928  0.5170  0.5905
# nb                            Naive Bayes    0.7298  0.8132  0.7625  0.4961
# knn                K Neighbors Classifier    0.7270  0.6741  0.3415  0.4832
# svm                   SVM - Linear Kernel    0.6456  0.0000  0.5694  0.4843
# ...

# %%
lr = create_model('lr')
plot_model(lr)

# %%
plot_model(plot='confusion_matrix', estimator=lr)

# %%
plot_model(plot='learning', estimator=lr)

# %%
plot_model(plot='error', estimator=lr)

# %%
plot_model(plot='vc', estimator=lr)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
# ...

# %%
plot_model(plot='feature', estimator=lr)

# %%
 plot_model(plot='pr', estimator=lr)

# %%
plot_model(plot='dimension', estimator=lr)

# %% [markdown]
# REGRESSIONE NO BISOGNA USARE CLASSIFICAZIONE

# %%
#from pycaret.regression import *
#reg1 = setup(data = df, target = 'Churn')
#best = compare_models()
